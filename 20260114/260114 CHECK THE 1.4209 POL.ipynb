# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

s="/content/drive/MyDrive/Colab Notebooks/RT/20260114/FITS/20260114-161822_SPECTRUM-PROJ01-GAL_01#_01#.fits"

# %%
h = fits.open(s, ignore_missing_end=True)
d = h[1].data
hdr = h[1].header
base = hdr["BASEFREQ"]
bw   = hdr["BANDWID"]
n = 1024
freq = base + (np.arange(n) + 0.5) * (bw / n)
freq = freq / 1e9

h
# Out:
# WARNING: File may have been truncated: actual file length (159660) is smaller than the expected size (161280) [astropy.io.fits.file]
# WARNING:astropy:File may have been truncated: actual file length (159660) is smaller than the expected size (161280)
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# DIAMETER =                    3  / TELESCOPE diameter                            [astropy.io.fits.card]
# WARNING:astropy:The following header keyword is invalid or follows an unrecognized non-standard convention:
# DIAMETER =                    3  / TELESCOPE diameter
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f6709927980>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7f6708802570>]

# %%
for f in s:
    h = fits.open(s, ignore_missing_end=True)
    d = h[1].data
    hdr = h[1].header
    base = hdr["BASEFREQ"]
    bw   = hdr["BANDWID"]
    n = 1024
    freq = base + (np.arange(n) + 0.5) * (bw / n)
    freq = freq / 1e9

    spec1 = np.mean(d.field(7)[0:], axis=0)   # left polarisation
    spec2 = np.mean(d.field(8)[0:], axis=0)   # right polarisation

    plt.figure()
    plt.plot(freq, spec1, label="Left pol")
    plt.plot(freq, spec2, label="Right pol")
    plt.xlabel("Frequency (GHz)")
    plt.ylabel("Intensity (ADC counts)")
    plt.xlim(1.4206,1.4209)

    plt.title(f"HI spectra ")
    plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_11482/184626132.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
